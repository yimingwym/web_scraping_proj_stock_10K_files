# %%
URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'

# %%
URL.format('ticker')
# Out:
# 'http://www.sec.gov/cgi-bin/browse-edgar?CIK=ticker&Find=Search&owner=exclude&action=getcompany'

# %%
import re, requests

def getCIKs(TICKERS):
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')    
    cik_dict = {}
    for ticker in TICKERS:
        f = requests.get(URL.format(ticker), stream = True)
        results = CIK_RE.findall(f.text)
        if len(results):
            results[0] = int(re.sub('\.[0]*', '.', results[0]))
            cik_dict[str(ticker).upper()] = str(results[0])
    f = open('cik_dict', 'w')   
    print(cik_dict)
    f.close()

getCIKs(['TSM'])
# Out:
# {'TSM': '1046179'}

# %%
import re, requests
URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
f = requests.get(URL.format('SATS'), stream = True)
CIK = CIK_RE.findall(f.text)[1]
# Out:
# '0001415404'

# %%
from bs4 import BeautifulSoup
import requests, re
# Out:
# 0001326801
# https://www.sec.gov/Archives/edgar/data/1326801/000132680117000007/fb-20161231.xml

# %%
response = requests.get('https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=0001065280&type=10-K&dateb=&owner=exclude&count=40').text
soup = BeautifulSoup(response, 'html.parser')
source = soup(text='10-K')[0].parent.parent.find_all('a')
source1 = source[0].attrs['href']
source1
# Out:
# '/Archives/edgar/data/1065280/000162828017000496/0001628280-17-000496-index.htm'

# %%
import random
rg = random.sample(range(1, 4678), 100)
company_list = result_com.iloc[:, 0]
company_try = company_list[rg]
############### current assets ###############
import requests, re
from bs4 import BeautifulSoup
def get_ascu(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assetscurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

ascu = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            else:
                print('currenassets no 10-K file entry for ' + ticker)
        else:
            print('currenassets no 10-K files for ' + ticker)
# Out:
# no 10-K files for ZPIN
# No CIK for VUZI
# No CIK for EQBK
# no 10-K files for NYMX
# no 10-K files for SNP
# no 10-K files for SSRI
# No CIK for WVVIP
# no 10-K files for TI
# no 10-K file entry for CRT
# no 10-K files for GIGM
# no 10-K files for ABIL
# no 10-K files for NETS
# no 10-K files for AUG
# no 10-K files for USLV
# No CIK for EAGLU
# no 10-K files for ANFI
# no 10-K files for PGH
# no 10-K files for SJR
# no 10-K files for ABX

# %%
ascu #11/20
# Out:
# {'AGEN': '91312202',
#  'AGLE': '66424000',
#  'ALOT': None,
#  'AMDA': '24097000',
#  'APLE': None,
#  'ARGS': '55501794',
#  'AT': '164900000',
#  'ATRS': '45264468',
#  'AWX': '14918000',
#  'BLVD': '987333',
#  'BONT': '829748000',
#  'CCCR': None,
#  'CPAH': None,
#  'CYTK': None,
#  'DGSE': '11136969',
#  'DHX': '70178000',
#  'DUKH': '8039000000',
#  'DXTR': '14410000',
#  'EGAN': '26354000',
#  'EPC': '1452000000',
#  'EQR': None,
#  'ETE': '6985000000',
#  'FALC': '9646766',
#  'FGL': None,
#  'FISV': '1728000000',
#  'FLEX': '8315126000',
#  'FPO': None,
#  'GGG': '503362000',
#  'GWRE': '707672000',
#  'HFC': '2851009000',
#  'HUBB': '1551300000',
#  'IDN': '3830318',
#  'IGC': None,
#  'IMH': None,
#  'IOSP': None,
#  'IPB': None,
#  'JMP': None,
#  'KELYA': '1214600000',
#  'KMG': '95348000',
#  'KNSL': None,
#  'KTWO': '159985000',
#  'LAND': None,
#  'LARK': None,
#  'LMNX': '173737000',
#  'LOV': '13747000',
#  'LVNTB': '3169000000',
#  'MDGL': '41207479',
# ...

# %%
URL = 'https://www.sec.gov/Archives/edgar/data/46765/000104746916016935/hp-20160930.xml'
nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
print(nums[0])
print(nums[1])
# Out:
# 46765
# 20160930

# %%
date = nums[1]
year = date[0:4]
month = date[4:6]
day = date[6:8]
print(year, month, day)
# Out:
# 2016 09 30

# %%
month_nozero = str(int(month))
attr2 = 'As_Of_' + month_nozero + '_' + day + '_' + year
attr3 = 'As_Of_' + year + '_' + month_nozero + '_' + day
attr4 = 'i' + '_' + year + '-' + month + '-' + day
print(attr4)
# Out:
# i_2016-09-30

# %%
company_list = result_com.iloc[:, 0]
company_try = company_list[0:20]
############### assets ###############
import requests, re
from bs4 import BeautifulSoup
def get_as(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assets', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

ass = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            else:
                print('assets no 10-K file entry for ' + ticker)
        else:
            print('assets no 10-K files for ' + ticker)
# Out:
# no 10-K files for AAU
# no 10-K files for ABX
# no 10-K files for ACH
# no 10-K files for AEM
# no 10-K files for AG
# no 10-K files for AGI
# no 10-K files for AGU
# No CIK for AKG
# no 10-K file entry for ALO

# %%
ass #11/20
# Out:
# {'ADES': '107296000',
#  'AEGN': '1193582000',
#  'AES': '36119000000',
#  'AGX': '644247000',
#  'AIN': '1263433000',
#  'AKS': '4036000000.0',
#  'ALB': '8161207000',
#  'AMRC': '797281000',
#  'AMRK': '437147000',
#  'AMRS': '129873000',
#  'AMTX': '77810000'}

# %%
import random
rg = random.sample(range(1, 4678), 100)
company_list = result_com.iloc[:, 0]
company_try = company_list[rg]
############### current liabilities ###############
import requests, re
from bs4 import BeautifulSoup
def get_li(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

licu = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            else:
                print('currentliabilities no 10-K file entry for ' + ticker)
        else:
            print('currentliabilities no 10-K files for ' + ticker)
# Out:
# no 10-K files for ABIL
# no 10-K files for CYAD
# no 10-K file entry for POT
# no 10-K files for MBLY
# no 10-K files for IBA
# no 10-K files for PLM
# no 10-K files for CPL
# no 10-K files for SPI
# No CIK for AKG
# no 10-K files for SNN
# no 10-K files for IPCI
# No CIK for BATRA
# no 10-K files for NAO
# no 10-K files for NVGN
# no 10-K files for IRCP
# no 10-K files for DNN
# No CIK for ORM
# no 10-K files for UMC
# no 10-K files for VVPR
# no 10-K files for DAC
# no 10-K files for ISF
# no 10-K file entry for MTR

# %%
licu #56/100
# Out:
# {'ACRX': '10191000',
#  'AKR': None,
#  'AKRX': '175555000',
#  'ALKS': '211993000',
#  'ANCX': None,
#  'ANTM': '21294400000',
#  'AOSL': '69480000',
#  'APLE': None,
#  'AVAV': '48063000',
#  'BBBY': '2032501000',
#  'BGCA': None,
#  'BOH': None,
#  'BUFF': '98827000',
#  'BWP': '332900000',
#  'CHTR': '9572000000',
#  'CKX': '132457',
#  'CLF': '391100000',
#  'CLI': None,
#  'CLSN': '8423287',
#  'CLW': '366520000',
#  'CMCO': '132517000',
#  'COP': None,
#  'CROX': '149140000',
#  'CRUS': '144075000',
#  'CYTK': None,
#  'EGLE': None,
#  'ESIO': '40768000',
#  'FEIM': None,
#  'FOLD': '110959000',
#  'FORD': '4169553',
#  'FRD': '2356590',
#  'GBLI': None,
#  'IFF': '898297000',
#  'INGN': '22845000',
#  'INTC': '20302000000',
#  'INTL': None,
#  'KEG': '116795000',
#  'KERX': '21551000',
#  'KEYW': '38091000',
#  'KSS': '2974000000',
#  'LOV': '7414000',
#  'LPSN': '74683000',
#  'MHLD': None,
#  'MMP': '481656000',
#  'MODN': '44244000',
#  'MRTN': '60670000',
# ...

# %%
import random
rg = random.sample(range(1, 4678), 100)
company_list = result_com.iloc[:, 0]
company_try = company_list[rg]
############### net income ###############
import requests, re
from bs4 import BeautifulSoup
def get_ni(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}).text     
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:netincomeloss', {'contextref' : attr}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr2}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr5}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr6}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr7}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr9}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr10}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr3}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr4}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr8}).text
        else:
            return None         
    else:
        return None

nein = {}       
for ticker in company_try:
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            else:
                print('netincome no 10-K file entry')
        else:
            print('netincome no 10-K files')
# Out:
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# No CIK for DRIO
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# No CIK for BTG
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K files
# no 10-K file entry
# no 10-K files
# no 10-K files

# %%
nein #48/100
# Out:
# {'ABCB': '72100000',
#  'ACAD': None,
#  'ADMP': None,
#  'ADP': '1492500000',
#  'AGM': '77334000',
#  'AHL': '203300000',
#  'ARTNA': '12954000',
#  'ASIX': None,
#  'BASI': None,
#  'BOX': None,
#  'BSM': '20188000',
#  'BYD': '418003000',
#  'CHH': '139371000',
#  'CHSP': '76706000',
#  'CMC': '54762000',
#  'CPF': '46992000',
#  'CPLA': '42969000',
#  'CSU': None,
#  'DF': '119929000',
#  'DLB': '185860000',
#  'DOW': '4318000000',
#  'EFC': '-16007000',
#  'EGLT': None,
#  'ELLI': '37776000',
#  'ENV': None,
#  'EVI': None,
#  'FB': '10217000000',
#  'FBIO': '-55095000',
#  'FDX': None,
#  'FWONK': '680000000',
#  'G': None,
#  'HCOM': None,
#  'HEP': '158241000',
#  'HONE': None,
#  'IBM': None,
#  'IGC': None,
#  'IRET': None,
#  'JSM': '250327000',
#  'KEY': '791000000',
#  'KEYW': '-25728000',
#  'LBTYA': '1705300000',
#  'LCA': '-4518',
#  'LEN': '911844000',
#  'MEET': None,
#  'NH': '-184102000',
#  'NSM': '19000000',
#  'OIS': None,
#  'OMER': '-66745000',
# ...

# %%
result_com = pd.read_csv('annual_return_all.csv')
result_com.head()
# Out:
#   symbols  annual_return            sector
# 0     AAU       0.366197  Basic_industries
# 1     ABX       1.078023  Basic_industries
# 2     ACH       0.297332  Basic_industries
# 3    ADES       0.212598  Basic_industries
# 4    AEGN       0.249341  Basic_industries

# %%
result_com.shape
# Out:
# (4678, 3)

# %%
result_com = pd.read_csv('annual_return_all.csv')
company_list = result_com.iloc[:, 0]
company_list
# Out:
# 0         AAU
# 1         ABX
# 2         ACH
# 3        ADES
# 4        AEGN
# 5         AEM
# 6         AES
# 7          AG
# 8         AGI
# 9         AGU
# 10        AGX
# 11        AIN
# 12        AKG
# 13        AKS
# 14        ALB
# 15        ALO
# 16       AMRC
# 17       AMRK
# 18       AMRS
# 19       AMTX
# 20       AMWD
# 21        APD
# 22       APWC
# 23       AQMS
# 24       ASIX
# 25        ASM
# 26        ATI
# 27         AU
# 28        AUG
# 29       AUMN
#         ...
# 4648     SAVE
# 4649       SB
# 4650     SBLK
# 4651    SBLKL
# 4652     SBNA
# 4653     SBNB
# 4654      SFL
# 4655     SHIP
# 4656     SINO
# 4657     SKYW
# 4658     SLTB
# 4659      SSW
# 4660     SSWN
# 4661      STB
# 4662     STNG
# 4663     SWFT
# 4664       TK
# 4665      TNP
# 4666     TOPS
# 4667      UAL
# 4668      ULH
# 4669      UNP
# 4670      UPS
# 4671     USAK
# 4672     USDP
# 4673     VLRS
# 4674     WERN
# 4675     YRCW
# 4676      ZNH
# 4677      ZTO
# ...

# %%
company_list = result_com.iloc[:, 0]
company_try = company_list[0:20]
############### shareholders' equity ###############
import requests, re
from bs4 import BeautifulSoup
def get_sheq(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:stockholdersequity', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:stockholdersequity', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr3}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr4}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr8}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr2}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr5}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr6}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr7}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr9}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

def get_ascu(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assetscurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None
    
def get_as(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assets', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None
    
def get_li(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

def get_ni(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}).text     
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:netincomeloss', {'contextref' : attr}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr2}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr5}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr6}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr7}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr9}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr10}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr3}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr4}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr8}).text
        else:
            return None         
    else:
        return None
    
sheq = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            else:
                print('shareholdersequity no 10-K file entry for ' + ticker)
        else:
            print('shareholdersequity no 10-K files for ' + ticker)
            
ascu = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            else:
                print('currenassets no 10-K file entry for ' + ticker)
        else:
            print('currenassets no 10-K files for ' + ticker)
            
ass = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            else:
                print('assets no 10-K file entry for ' + ticker)
        else:
            print('assets no 10-K files for ' + ticker)
            
licu = {}
for ticker in company_try:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            else:
                print('currentliabilities no 10-K file entry for ' + ticker)
        else:
            print('currentliabilities no 10-K files for ' + ticker)
            
nein = {}       
for ticker in company_try:
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    f = requests.get(URL.format(ticker), stream = True)
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        response = requests.get(URL_COMPANY.format(CIK)).text
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = requests.get('https://www.sec.gov' + source1).text
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            else:
                print('netincome no 10-K file entry')
        else:
            print('netincome no 10-K files')
# Out:
# no 10-K files for AAU
# no 10-K files for ABX
# no 10-K files for ACH
# no 10-K files for AEM
# no 10-K files for AG
# no 10-K files for AGI
# no 10-K files for AGU
# No CIK for AKG
# no 10-K file entry for ALO

# %%
sheq #53/100
# Out:
# {'ADES': '76165000',
#  'AEGN': '568500000',
#  'AES': None,
#  'AGX': '291632000',
#  'AIN': '507523000',
#  'AKS': '-272200000',
#  'ALB': '3795062000',
#  'AMRC': None,
#  'AMRK': '63309000',
#  'AMRS': '-184445000',
#  'AMTX': '-49813000'}

# %%
import requests, re
from bs4 import BeautifulSoup
import pandas as pd
import time

result_com = pd.read_csv('annual_return_all.csv')
company_list = result_com.iloc[:, 0]

def get_sheq(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:stockholdersequity', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:stockholdersequity', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:stockholdersequity', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr3}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr4}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr8}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr2}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr5}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr6}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr7}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr9}).text
        elif tt.find('us-gaap:stockholdersequity', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:stockholdersequity', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

def get_ascu(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assetscurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assetscurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assetscurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assetscurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None
    
def get_as(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:assets', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:assets', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr3}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr4}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr8}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr2}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr5}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr6}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr7}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr9}).text
        elif tt.find('us-gaap:assets', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:assets', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None
    
def get_li(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:liabilitiescurrent', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr3}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr4}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr8}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr2}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr5}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr6}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr7}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr9}).text
        elif tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:liabilitiescurrent', {'contextref' : attr10}).text
        else:
            return None
    else:
        return None

def get_ni(URL):
    tt = requests.get(URL).text
    tt = BeautifulSoup(tt, 'lxml')
    if tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FI2016Q4'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'FD2016Q4YTD'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'P01_01_2016To12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE11030---1610-K0014_STD_0_20161231_0'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'Duration_1_1_2016_To_12_31_2016'}).text
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'c20160101to20161231'}).text     
    elif tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}) != None:
        return tt.find('us-gaap:netincomeloss', {'contextref' : 'eol_PE8528----1610-K0009_STD_0_20160630_0'}).text
    elif re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL) != []:
        nums = re.findall(r'https://www.sec.gov/Archives/edgar/data/([0-9]*)/[0-9]*/.*([0-9]{8}).*.xml', URL)[0]
        str1 = nums[0].zfill(10)
        str2 = '_' + nums[1]
        attr = 'C_' + str1 + str2
        date = nums[1]
        year = date[0:4]
        month = date[4:6]
        day = date[6:8]
        month_nozero = str(int(month))
        day_nozero = str(int(day))
        attr2 = 'As_Of_' + month_nozero + '_' + day_nozero + '_' + year
        attr3 = 'i' + '_' + year + '-' + month + '-' + day
        attr4 = 'AsOf' + year + '-' + month + '-' + day
        attr5 = 'As_Of_' + month + '_' + day + '_' + year
        attr6 = 'As_Of_' + year + '_' + month + '_' + day
        attr7 = 'As_Of_' + year + '_' + month_nozero + '_' + day_nozero
        attr8 = 'PAsOn' + month + '_' + day + '_' + year
        attr9 = 'PAsOn' + month_nozero + '_' + day + '_' + year
        attr10 = 'c' + nums[1]
        if tt.find('us-gaap:netincomeloss', {'contextref' : attr}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr2}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr2}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr5}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr5}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr6}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr6}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr7}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr7}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr9}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr9}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr10}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr10}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr3}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr3}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr4}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr4}).text
        elif tt.find('us-gaap:netincomeloss', {'contextref' : attr8}) != None:
            return tt.find('us-gaap:netincomeloss', {'contextref' : attr8}).text
        else:
            return None         
    else:
        return None
    
sheq = {}
for ticker in company_list:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')
    
    f = ''  
    while f == '':
        try:
            f = requests.get(URL.format(ticker), stream = True)
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 60 seconds")
            print("ZZzzzz...")
            time.sleep(60)
            print("Was a nice sleep, now let me continue...")
            continue
    
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        
        response = ''  
        while response == '':
            try:
                response = requests.get(URL_COMPANY.format(CIK)).text
            except:
                print("Connection refused by the server..")
                print("Let me sleep for 60 seconds")
                print("ZZzzzz...")
                time.sleep(60)
                print("Was a nice sleep, now let me continue...")
                continue
        
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = ''
            while response1 == '':
                try:
                    response1 = requests.get('https://www.sec.gov' + source1).text
                except:
                    print("Connection refused by the server..")
                    print("Let me sleep for 60 seconds")
                    print("ZZzzzz...")
                    time.sleep(60)
                    print("Was a nice sleep, now let me continue...")
                    continue
            
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                sheq[ticker] = get_sheq(xbrlurl)
            else:
                print('shareholdersequity no 10-K file entry for ' + ticker)
        else:
            print('shareholdersequity no 10-K files for ' + ticker)
            
ascu = {}
for ticker in company_list:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')

    f = ''  
    while f == '':
        try:
            f = requests.get(URL.format(ticker), stream = True)
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 60 seconds")
            print("ZZzzzz...")
            time.sleep(60)
            print("Was a nice sleep, now let me continue...")
            continue
    
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'

        response = ''  
        while response == '':
            try:
                response = requests.get(URL_COMPANY.format(CIK)).text
            except:
                print("Connection refused by the server..")
                print("Let me sleep for 60 seconds")
                print("ZZzzzz...")
                time.sleep(60)
                print("Was a nice sleep, now let me continue...")
                continue
        
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = ''
            while response1 == '':
                try:
                    response1 = requests.get('https://www.sec.gov' + source1).text
                except:
                    print("Connection refused by the server..")
                    print("Let me sleep for 60 seconds")
                    print("ZZzzzz...")
                    time.sleep(60)
                    print("Was a nice sleep, now let me continue...")
                    continue
            
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ascu[ticker] = get_ascu(xbrlurl)
            else:
                print('currenassets no 10-K file entry for ' + ticker)
        else:
            print('currenassets no 10-K files for ' + ticker)
            
ass = {}
for ticker in company_list:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')

    f = ''  
    while f == '':
        try:
            f = requests.get(URL.format(ticker), stream = True)
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 60 seconds")
            print("ZZzzzz...")
            time.sleep(60)
            print("Was a nice sleep, now let me continue...")
            continue
    
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'

        response = ''  
        while response == '':
            try:
                response = requests.get(URL_COMPANY.format(CIK)).text
            except:
                print("Connection refused by the server..")
                print("Let me sleep for 60 seconds")
                print("ZZzzzz...")
                time.sleep(60)
                print("Was a nice sleep, now let me continue...")
                continue
        
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = ''
            while response1 == '':
                try:
                    response1 = requests.get('https://www.sec.gov' + source1).text
                except:
                    print("Connection refused by the server..")
                    print("Let me sleep for 60 seconds")
                    print("ZZzzzz...")
                    time.sleep(60)
                    print("Was a nice sleep, now let me continue...")
                    continue
            
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                ass[ticker] = get_as(xbrlurl)
            else:
                print('assets no 10-K file entry for ' + ticker)
        else:
            print('assets no 10-K files for ' + ticker)
            
licu = {}
for ticker in company_list:       
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')

    f = ''  
    while f == '':
        try:
            f = requests.get(URL.format(ticker), stream = True)
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 60 seconds")
            print("ZZzzzz...")
            time.sleep(60)
            print("Was a nice sleep, now let me continue...")
            continue
    
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'
        
        response = ''  
        while response == '':
            try:
                response = requests.get(URL_COMPANY.format(CIK)).text
            except:
                print("Connection refused by the server..")
                print("Let me sleep for 60 seconds")
                print("ZZzzzz...")
                time.sleep(60)
                print("Was a nice sleep, now let me continue...")
                continue
        
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = ''
            while response1 == '':
                try:
                    response1 = requests.get('https://www.sec.gov' + source1).text
                except:
                    print("Connection refused by the server..")
                    print("Let me sleep for 60 seconds")
                    print("ZZzzzz...")
                    time.sleep(60)
                    print("Was a nice sleep, now let me continue...")
                    continue
            
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                licu[ticker] = get_li(xbrlurl)
            else:
                print('currentliabilities no 10-K file entry for ' + ticker)
        else:
            print('currentliabilities no 10-K files for ' + ticker)
            
nein = {}       
for ticker in company_list:
    URL = 'http://www.sec.gov/cgi-bin/browse-edgar?CIK={}&Find=Search&owner=exclude&action=getcompany'
    CIK_RE = re.compile(r'.*CIK=(\d{10}).*')

    f = ''  
    while f == '':
        try:
            f = requests.get(URL.format(ticker), stream = True)
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 60 seconds")
            print("ZZzzzz...")
            time.sleep(60)
            print("Was a nice sleep, now let me continue...")
            continue
    
    if CIK_RE.findall(f.text) == []:
        print('No CIK for ' + ticker)
    else:
        CIK = CIK_RE.findall(f.text)[1]

        URL_COMPANY = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-K&dateb=&owner=exclude&count=40'

        response = ''  
        while response == '':
            try:
                response = requests.get(URL_COMPANY.format(CIK)).text
            except:
                print("Connection refused by the server..")
                print("Let me sleep for 60 seconds")
                print("ZZzzzz...")
                time.sleep(60)
                print("Was a nice sleep, now let me continue...")
                continue
        
        soup = BeautifulSoup(response, 'html.parser')
        if soup(text='10-K') != []:
            source = soup(text='10-K')[0].parent.parent.find_all('a')
            source1 = source[0].attrs['href']

            response1 = ''
            while response1 == '':
                try:
                    response1 = requests.get('https://www.sec.gov' + source1).text
                except:
                    print("Connection refused by the server..")
                    print("Let me sleep for 60 seconds")
                    print("ZZzzzz...")
                    time.sleep(60)
                    print("Was a nice sleep, now let me continue...")
                    continue
            
            soup1 = BeautifulSoup(response1, 'html.parser')
            if soup1(text='XBRL INSTANCE DOCUMENT') != []:
                source2 = soup1(text='XBRL INSTANCE DOCUMENT')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='XBRL INSTANCE FILE') != []:
                source2 = soup1(text='XBRL INSTANCE FILE')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EX-101.INS') != []:
                source2 = soup1(text='EX-101.INS')[0].parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            elif soup1(text='EXTRACTED') != []:
                source2 = soup1(text='EXTRACTED')[0].parent.parent.parent.find_all('a')
                xbrlurl = 'https://www.sec.gov' + source2[0].attrs['href']
                nein[ticker] = get_ni(xbrlurl)
            else:
                print('netincome no 10-K file entry')
        else:
            print('netincome no 10-K files')
# Out:
# shareholdersequity no 10-K files for AAU
# shareholdersequity no 10-K files for ABX
# shareholdersequity no 10-K files for ACH
# shareholdersequity no 10-K files for AEM
# shareholdersequity no 10-K files for AG
# shareholdersequity no 10-K files for AGI
# shareholdersequity no 10-K files for AGU
# No CIK for AKG
# shareholdersequity no 10-K file entry for ALO
# shareholdersequity no 10-K files for APWC
# shareholdersequity no 10-K files for ASM
# shareholdersequity no 10-K files for AU
# shareholdersequity no 10-K files for AUG
# shareholdersequity no 10-K files for AUY
# shareholdersequity no 10-K files for AXU
# shareholdersequity no 10-K files for BAA
# No CIK for BAK
# shareholdersequity no 10-K files for BBU
# shareholdersequity no 10-K files for BHP
# No CIK for BTG
# shareholdersequity no 10-K files for BVN
# shareholdersequity no 10-K files for CCJ
# shareholdersequity no 10-K file entry for CHNR
# shareholdersequity no 10-K files for CSTM
# ...

# %%
len(nein)
# Out:
# 3786

# %%
df_nein = pd.DataFrame.from_dict(nein, orient='index')
df_nein['symbol'] = df_nein.index
df_nein.columns = ['net_income', 'symbol']

# %%
df_nein
# Out:
#         net_income symbol
# ADES      97678000   ADES
# AEGN      29488000   AEGN
# AES    -1130000000    AES
# AGX           None    AGX
# AIN           None    AIN
# AKS       -7800000    AKS
# ALB      643675000    ALB
# AMRC      11997000   AMRC
# AMRK          None   AMRK
# AMRS          None   AMRS
# AMTX          None   AMTX
# AMWD      58723000   AMWD
# APD           None    APD
# AQMS          None   AQMS
# ASIX          None   ASIX
# ATI     -640900000    ATI
# AUMN          None   AUMN
# AVD           None    AVD
# AXTA      41800000   AXTA
# BCPC      55972000   BCPC
# BDC      128003000    BDC
# BGC      -93800000    BGC
# BIOA          None   BIOA
# BLD       72606000    BLD
# CADC          None   CADC
# CBI     -313169000    CBI
# CBT           None    CBT
# CC            None     CC
# CCC           None    CCC
# CDE       55352000    CDE
# ...            ...    ...
# KNX           None    KNX
# KSU      478100000    KSU
# LPG           None    LPG
# ...

# %%
df_ass = pd.DataFrame.from_dict(ass, orient='index')
df_ass['symbol'] = df_ass.index
df_ass.columns = ['assets', 'symbol']
df_ass
# Out:
#              assets symbol
# ADES      107296000   ADES
# AEGN     1193582000   AEGN
# AES     36119000000    AES
# AGX       644247000    AGX
# AIN      1263433000    AIN
# AKS    4036000000.0    AKS
# ALB      8161207000    ALB
# AMRC      797281000   AMRC
# AMRK      437147000   AMRK
# AMRS      129873000   AMRS
# AMTX       77810000   AMTX
# AMWD      466360000   AMWD
# APD            None    APD
# AQMS       71529000   AQMS
# ASIX           None   ASIX
# ATI      5170000000    ATI
# AUMN       14008000   AUMN
# AVD       429956000    AVD
# AXTA     5854800000   AXTA
# BCPC      948626000   BCPC
# BDC      3806803000    BDC
# BGC      2241600000    BGC
# BIOA      161330465   BIOA
# BLD      1690119000    BLD
# CADC           None   CADC
# CBI      7839420000    CBI
# CBT      3044000000    CBT
# CC       6060000000     CC
# CCC       775218000    CCC
# CDE      1318909000    CDE
# ...             ...    ...
# KNX      1078525000    KNX
# KSU      8817500000    KSU
# ...

# %%
df_ascu = pd.DataFrame.from_dict(ascu, orient='index')
df_ascu['symbol'] = df_ascu.index
df_ascu.columns = ['current_assets', 'symbol']
df_ascu
# Out:
#       current_assets symbol
# ADES        38908000   ADES
# AEGN       532237000   AEGN
# AES       6411000000    AES
# AGX        587949000    AGX
# AIN        501305000    AIN
# AKS       1823700000    AKS
# ALB       3306618000    ALB
# AMRC       226061000   AMRC
# AMRK       418261000   AMRK
# AMRS        59123000   AMRS
# AMTX         7045000   AMTX
# AMWD       302209000   AMWD
# APD             None    APD
# AQMS        27370000   AQMS
# ASIX            None   ASIX
# ATI       1766500000    ATI
# AUMN         4773000   AUMN
# AVD        227075000    AVD
# AXTA      1920000000   AXTA
# BCPC       188442000   BCPC
# BDC       1478952000    BDC
# BGC       1599200000    BGC
# BIOA        31421552   BIOA
# BLD        526553000    BLD
# CADC            None   CADC
# CBI       2541752000    CBI
# CBT       1089000000    CBT
# CC        2553000000     CC
# CCC        291590000    CCC
# CDE        410787000    CDE
# ...              ...    ...
# KNX        190191000    KNX
# ...

# %%
df_licu = pd.DataFrame.from_dict(licu, orient='index')
df_licu['symbol'] = df_licu.index
df_licu.columns = ['current_liabilities', 'symbol']
df_licu
# Out:
#       current_liabilities symbol
# ADES             23711000   ADES
# AEGN            230601000   AEGN
# AES            5272000000    AES
# AGX             350724000    AGX
# AIN             200009000    AIN
# AKS             865300000    AKS
# ALB            1140103000    ALB
# AMRC            190602000   AMRC
# AMRK            366593000   AMRK
# AMRS            109868000   AMRS
# AMTX             27216000   AMTX
# AMWD             92313000   AMWD
# APD                  None    APD
# AQMS              4031000   AQMS
# ASIX                 None   ASIX
# ATI             708700000    ATI
# AUMN              1248000   AUMN
# AVD              97074000    AVD
# AXTA            919700000   AXTA
# BCPC            101008000   BCPC
# BDC             570279000    BDC
# BGC             901100000    BGC
# BIOA             45304953   BIOA
# BLD             325933000    BLD
# CADC                 None   CADC
# CBI            4536249000    CBI
# CBT             398000000    CBT
# ...

# %%
df_sheq = pd.DataFrame.from_dict(sheq, orient='index')
df_sheq['symbol'] = df_sheq.index
df_sheq.columns = ['shareholders_equity', 'symbol']
df_sheq
# Out:
#       shareholders_equity symbol
# ADES             76165000   ADES
# AEGN            568500000   AEGN
# AES                  None    AES
# AGX             291632000    AGX
# AIN             507523000    AIN
# AKS            -272200000    AKS
# ALB            3795062000    ALB
# AMRC                 None   AMRC
# AMRK             63309000   AMRK
# AMRS           -184445000   AMRS
# AMTX            -49813000   AMTX
# AMWD            280761000   AMWD
# APD                  None    APD
# AQMS             56990000   AQMS
# ASIX                 None   ASIX
# ATI            1355200000    ATI
# AUMN              8362000   AUMN
# AVD             282190000    AVD
# AXTA           1136100000   AXTA
# BCPC            521033000   BCPC
# BDC            1460313000    BDC
# BGC             153100000    BGC
# BIOA             48490900   BIOA
# BLD             972547000    BLD
# CADC                 None   CADC
# CBI            1413538000    CBI
# CBT            1274000000    CBT
# ...

# %%
df_nein.net_income = df_nein.net_income.astype(float)
df_nein = df_nein.dropna()
df_nein
# Out:
#         net_income symbol
# ADES  9.767800e+07   ADES
# AEGN  2.948800e+07   AEGN
# AES  -1.130000e+09    AES
# AKS  -7.800000e+06    AKS
# ALB   6.436750e+08    ALB
# AMRC  1.199700e+07   AMRC
# AMWD  5.872300e+07   AMWD
# ATI  -6.409000e+08    ATI
# AXTA  4.180000e+07   AXTA
# BCPC  5.597200e+07   BCPC
# BDC   1.280030e+08    BDC
# BGC  -9.380000e+07    BGC
# BLD   7.260600e+07    BLD
# CBI  -3.131690e+08    CBI
# CDE   5.535200e+07    CDE
# CDXS -8.558000e+06   CDXS
# CE    9.000000e+08     CE
# CENX -2.524150e+08   CENX
# CINR  4.140000e+07   CINR
# CLF   1.741000e+08    CLF
# CLW   4.955400e+07    CLW
# CMC   5.476200e+07    CMC
# CMP   1.627000e+08    CMP
# CRS   1.130000e+07    CRS
# CSL   2.501000e+08    CSL
# CSWI  2.547100e+07   CSWI
# CTIB  6.525380e+05   CTIB
# CVA  -4.000000e+06    CVA
# CVCO  2.854100e+07   CVCO
# DD    2.513000e+09     DD
# ...            ...    ...
# ZEN  -1.037990e+08    ZEN
# ALGT  2.195900e+08   ALGT
# ALK   8.140000e+08    ALK
# ...

# %%
df_nein.to_csv('nein.csv')

# %%
df_ass.assets = df_ass.assets.astype(float)
df_ass = df_ass.dropna()
df_ass.to_csv('ass.csv')
df_ass
# Out:
#             assets symbol
# ADES  1.072960e+08   ADES
# AEGN  1.193582e+09   AEGN
# AES   3.611900e+10    AES
# AGX   6.442470e+08    AGX
# AIN   1.263433e+09    AIN
# AKS   4.036000e+09    AKS
# ALB   8.161207e+09    ALB
# AMRC  7.972810e+08   AMRC
# AMRK  4.371470e+08   AMRK
# AMRS  1.298730e+08   AMRS
# AMTX  7.781000e+07   AMTX
# AMWD  4.663600e+08   AMWD
# AQMS  7.152900e+07   AQMS
# ATI   5.170000e+09    ATI
# AUMN  1.400800e+07   AUMN
# AVD   4.299560e+08    AVD
# AXTA  5.854800e+09   AXTA
# BCPC  9.486260e+08   BCPC
# BDC   3.806803e+09    BDC
# BGC   2.241600e+09    BGC
# BIOA  1.613305e+08   BIOA
# BLD   1.690119e+09    BLD
# CBI   7.839420e+09    CBI
# CBT   3.044000e+09    CBT
# CC    6.060000e+09     CC
# CCC   7.752180e+08    CCC
# CDE   1.318909e+09    CDE
# CDXS  3.564800e+07   CDXS
# CE    8.357000e+09     CE
# CENX  1.540327e+09   CENX
# ...            ...    ...
# GWR   7.634958e+09    GWR
# HA    2.708601e+09     HA
# HTLD  7.382280e+08   HTLD
# ...

# %%
df_ascu.current_assets = df_ascu.current_assets.astype(float)
df_ascu = df_ascu.dropna()
df_ascu.to_csv('ascu.csv')
df_ascu
# Out:
#       current_assets symbol
# ADES    3.890800e+07   ADES
# AEGN    5.322370e+08   AEGN
# AES     6.411000e+09    AES
# AGX     5.879490e+08    AGX
# AIN     5.013050e+08    AIN
# AKS     1.823700e+09    AKS
# ALB     3.306618e+09    ALB
# AMRC    2.260610e+08   AMRC
# AMRK    4.182610e+08   AMRK
# AMRS    5.912300e+07   AMRS
# AMTX    7.045000e+06   AMTX
# AMWD    3.022090e+08   AMWD
# AQMS    2.737000e+07   AQMS
# ATI     1.766500e+09    ATI
# AUMN    4.773000e+06   AUMN
# AVD     2.270750e+08    AVD
# AXTA    1.920000e+09   AXTA
# BCPC    1.884420e+08   BCPC
# BDC     1.478952e+09    BDC
# BGC     1.599200e+09    BGC
# BIOA    3.142155e+07   BIOA
# BLD     5.265530e+08    BLD
# CBI     2.541752e+09    CBI
# CBT     1.089000e+09    CBT
# CC      2.553000e+09     CC
# CCC     2.915900e+08    CCC
# CDE     4.107870e+08    CDE
# CDXS    2.722700e+07   CDXS
# CE      2.472000e+09     CE
# CENX    4.406220e+08   CENX
# ...              ...    ...
# GWR     4.853380e+08    GWR
# ...

# %%
df_licu.current_liabilities = df_licu.current_liabilities.astype(float)
df_licu = df_licu.dropna()
df_licu.to_csv('licu.csv')
df_licu
# Out:
#       current_liabilities symbol
# ADES         2.371100e+07   ADES
# AEGN         2.306010e+08   AEGN
# AES          5.272000e+09    AES
# AGX          3.507240e+08    AGX
# AIN          2.000090e+08    AIN
# AKS          8.653000e+08    AKS
# ALB          1.140103e+09    ALB
# AMRC         1.906020e+08   AMRC
# AMRK         3.665930e+08   AMRK
# AMRS         1.098680e+08   AMRS
# AMTX         2.721600e+07   AMTX
# AMWD         9.231300e+07   AMWD
# AQMS         4.031000e+06   AQMS
# ATI          7.087000e+08    ATI
# AUMN         1.248000e+06   AUMN
# AVD          9.707400e+07    AVD
# AXTA         9.197000e+08   AXTA
# BCPC         1.010080e+08   BCPC
# BDC          5.702790e+08    BDC
# BGC          9.011000e+08    BGC
# BIOA         4.530495e+07   BIOA
# BLD          3.259330e+08    BLD
# CBI          4.536249e+09    CBI
# CBT          3.980000e+08    CBT
# CC           1.771000e+09     CC
# CCC          1.006550e+08    CCC
# CDE          1.166340e+08    CDE
# ...

# %%
df_sheq.shareholders_equity = df_sheq.shareholders_equity.astype(float)
df_sheq = df_sheq.dropna()
df_sheq.to_csv('sheq.csv')
df_sheq
# Out:
#       shareholders_equity symbol
# ADES         7.616500e+07   ADES
# AEGN         5.685000e+08   AEGN
# AGX          2.916320e+08    AGX
# AIN          5.075230e+08    AIN
# AKS         -2.722000e+08    AKS
# ALB          3.795062e+09    ALB
# AMRK         6.330900e+07   AMRK
# AMRS        -1.844450e+08   AMRS
# AMTX        -4.981300e+07   AMTX
# AMWD         2.807610e+08   AMWD
# AQMS         5.699000e+07   AQMS
# ATI          1.355200e+09    ATI
# AUMN         8.362000e+06   AUMN
# AVD          2.821900e+08    AVD
# AXTA         1.136100e+09   AXTA
# BCPC         5.210330e+08   BCPC
# BDC          1.460313e+09    BDC
# BGC          1.531000e+08    BGC
# BIOA         4.849090e+07   BIOA
# BLD          9.725470e+08    BLD
# CBI          1.413538e+09    CBI
# CBT          1.274000e+09    CBT
# CC           1.000000e+08     CC
# CCC          3.811430e+08    CCC
# CDE          7.684870e+08    CDE
# CDXS         1.909900e+07   CDXS
# CE           2.588000e+09     CE
# ...

# %%
df_nein.head()
# Out:
#         net_income symbol
# ADES  9.767800e+07   ADES
# AEGN  2.948800e+07   AEGN
# AES  -1.130000e+09    AES
# AKS  -7.800000e+06    AKS
# ALB   6.436750e+08    ALB

# %%
df_sheq.head()
# Out:
#       shareholders_equity symbol
# ADES           76165000.0   ADES
# AEGN          568500000.0   AEGN
# AGX           291632000.0    AGX
# AIN           507523000.0    AIN
# AKS          -272200000.0    AKS

# %%
df_ascu.head()
# Out:
#       current_assets symbol
# ADES    3.890800e+07   ADES
# AEGN    5.322370e+08   AEGN
# AES     6.411000e+09    AES
# AGX     5.879490e+08    AGX
# AIN     5.013050e+08    AIN

# %%
df_ass.head()
# Out:
#             assets symbol
# ADES  1.072960e+08   ADES
# AEGN  1.193582e+09   AEGN
# AES   3.611900e+10    AES
# AGX   6.442470e+08    AGX
# AIN   1.263433e+09    AIN

# %%
df_licu.head()
# Out:
#       current_liabilities symbol
# ADES         2.371100e+07   ADES
# AEGN         2.306010e+08   AEGN
# AES          5.272000e+09    AES
# AGX          3.507240e+08    AGX
# AIN          2.000090e+08    AIN
